# %%
import requests
uri = "https://ai.ruc.edu.cn/"
headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get(uri, headers=headers)

# %%
print(r)
# Out:
# <Response [200]>

# %%
print(type(r))
print("Status code: ", r.status_code)
print("Reponse header: ", r.headers)
print("Content-type: ", r._content)
# Out:
# <class 'requests.models.Response'>
# Status code:  200
# Reponse header:  {'Connection': 'close', 'Transfer-Encoding': 'chunked', 'Content-Encoding': 'gzip', 'Content-Type': 'text/html', 'Date': 'Tue, 27 Aug 2024 00:41:43 GMT', 'Etag': 'W/"e8de-620924f0055c0"', 'Last-Modified': 'Mon, 26 Aug 2024 08:57:03 GMT', 'Server': 'none'}
# ...

# %%
r = requests.get("https://ai.ruc.edu.cn/nothing", headers=headers)
print(r.status_code)
# Out:
# 404

# %% [markdown]
# beautifulsoup 处理网站编码缺失，可不可以直接处理r.content

# %%
def get_html(uri, headers={}, timeout=30):
    try:
        r = requests.get(uri, headers=headers, timeout=timeout)
        r.raise_for_status()
        return r.text
    except:
        return None

# %%
uri = "http://ai.ruc.edu.cn/"
headers = {'user-agent': 'my-app/0.0.1'}
print(get_html(uri, headers=headers))
# Out:
# <!DOCTYPE html>
# <html lang="zh">
# <head>
# 	<meta charset="utf-8" name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">
# 	<meta http-equiv="X-UA-Compatible" content="IE=11,10,9,edge">
# 	<meta name="keywords" content="é¦é¡µ_ä¸­å½äººæ°å¤§å­¦é«ç´äººå·¥æºè½å­¦é¢">
# 	<meta name="description" content="é¦é¡µ_ä¸­å½äººæ°å¤§å­¦é«ç´äººå·¥æºè½å­¦é¢">
#  	<meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,Chrome=1">
# 	<title>é¦é¡µ_ä¸­å½äººæ°å¤§å­¦é«ç´äººå·¥æºè½å­¦é¢</title>
# 	<link rel="stylesheet" href="css/swiper.css?v=1724662623077">
# <link rel="stylesheet" href="css/animate.css?v=1724662623077">
# <link rel="stylesheet" href="css/bootstrap.min.css?v=1724662623077">
# <link rel="stylesheet" href="css/cn_ruc_style.css?v=3.0">
# <link rel="stylesheet" href="css/sina-nav-ruc.css?v=1.0">
#  <link rel="stylesheet" href="css/font-awesome.css?v=1.0">
#
# ...

# %% [markdown]
# 显然原text出现了乱码，访问content会发现content-type没有写charset

# %%
r = requests.get(uri, headers=headers)
r.encoding = 'utf-8'
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh">
# <head>
# 	<meta charset="utf-8" name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">
# 	<meta http-equiv="X-UA-Compatible" content="IE=11,10,9,edge">
# 	<meta name="keywords" content="首页_中国人民大学高瓴人工智能学院">
# 	<meta name="description" content="首页_中国人民大学高瓴人工智能学院">
#  	<meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,Chrome=1">
# 	<title>首页_中国人民大学高瓴人工智能学院</title>
# 	<link rel="stylesheet" href="css/swiper.css?v=1724662623077">
# <link rel="stylesheet" href="css/animate.css?v=1724662623077">
# <link rel="stylesheet" href="css/bootstrap.min.css?v=1724662623077">
# <link rel="stylesheet" href="css/cn_ruc_style.css?v=3.0">
# <link rel="stylesheet" href="css/sina-nav-ruc.css?v=1.0">
#  <link rel="stylesheet" href="css/font-awesome.css?v=1.0">
#
# <script src="js/jquery.min.js?v=1724662623077"></script>
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')
soup.find_all(class_='span_title')
# Out:
# [<span class="span_title"><a href="newslist/newsdetail/20240809100.html" title="中国人民大学与百川智能成立大模型联合实验室"><i class="fa fa-caret-right"></i>  中国人民大学与百川智能成立大模型联合实验室</a> </span>,
#  <span class="span_title"><a href="newslist/newsdetail/20240726003.html" title="“智汇·拥抱AI新未来”北京人工智能产业创新发展人才论坛在中国人民大学举办"><i class="fa fa-caret-right"></i>  “智汇·拥抱AI新未来”北京人工智能产业创新发展人才论坛在中国人民大学举办</a> </span>,
#  <span class="span_title"><a href="newslist/newsdetail/20240726002.html" title="先锋社会实践 | 扎根祖国大地，以科技赋能乡村发展"><i class="fa fa-caret-right"></i>  先锋社会实践 | 扎根祖国大地，以科技赋能乡村发展</a> </span>,
#  <span class="span_title"><a href="newslist/newsdetail/20240725003.html" title="我院文继荣、李崇轩参加ACM 2024中国图灵大会并获奖项"><i class="fa fa-caret-right"></i>  我院文继荣、李崇轩参加ACM 2024中国图灵大会并获奖项</a> </span>,
#  <span class="span_title"><a href="newslist/newsdetail/20240725001.html" title="我院师生论文获SIGIR 2024最佳论文奖、最佳论文提名奖"><i class="fa fa-caret-right"></i>  我院师生论文获SIGIR 2024最佳论文奖、最佳论文提名奖</a> </span>,
# ...
